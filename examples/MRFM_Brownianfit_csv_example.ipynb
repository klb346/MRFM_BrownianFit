# %% [markdown]
# # MRFM_BrownianFit h5 examples
# 08/5/2025
#
# ## Preliminaries
#
# ### import libraries

# %%
import pandas as pd
from MRFM_BrownianFit.LabVIEW_int import LVprocessing
import os

# %% [markdown]
# ### read in the data from an csv file
#
# (8 averages from 07/01/2025)

# %%
# set folder path for data if not in same folder as notebook
path = r".\\"
os.chdir(path)

# read data from csv file into data frame
df = pd.read_csv('brownian_k_20250701_8avgs.csv')


# extract data - change to column names as necessary
x= list(df['freq'])
y = list(df['power'])


# set temp and n_avgs for sample
temp = float(294.5)
n_avgs = int(8)

# check that data is read as expected
print( len(x), len(y))
print(temp, n_avgs)
# Out:
# 2000 2000
# 294.5 8

# %% [markdown]
# ## Run fit using MRFM_BrownianFit
#
# ### Use LVprocessing to initialize brownian_fit class

# %%
# set path to folder for saved plots and reports
path = r".\\example_outputs"

# set root name for plots and reports
name="20250701_baysian_8avgs"

#call LVprocessing class
data = LVprocessing(n_avgs, temp, x, y, name=name, path=path)

# %% [markdown]
# ### do_fit()

# %%
# run fitting function - this example will not generate the .tex report
data.do_fit()

# use brownian_fit functions to generate the fit plot and the residuals cdf
data.fit.plot_fit()
data.fit.residuals_CDF()

# print the fit summary
data.fit.result["leastsq"]
# Out:
# c:\Users\Katri\miniconda3\envs\mrfm_emcee\lib\site-packages\uncertainties\core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# <h2>Fit Result</h2> <p>Model: Model(_brownian)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>34</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>1978</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 2138.98321</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.08357812</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 162.767322</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 185.126688</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.96076771</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>Gamma</td><td style='text-align:left'> 3.1804e-11</td><td style='text-align:left'> 6.3762e-12</td><td style='text-align:left'>(20.05%)</td><td style='text-align:left'>1e-11</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>tau0</td><td style='text-align:left'> 144.462463</td><td style='text-align:left'> 14.7068322</td><td style='text-align:left'>(10.18%)</td><td style='text-align:left'>200.0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>f0</td><td style='text-align:left'> 8.23888678</td><td style='text-align:left'> 1.1057e-04</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>8.239</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>baseline</td><td style='text-align:left'> 13.4963765</td><td style='text-align:left'> 0.17397855</td><td style='text-align:left'>(1.29%)</td><td style='text-align:left'>14.40868686868687</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>Gamma</td><td style='text-align:left'>tau0</td><td style='text-align:right'>-0.9949</td></tr></table>

# %% [markdown]
# ### plot_report()

# %%
# run fitting function - this example will generate the .tex report
data.plot_report()

# use brownian_fit functions to generate the fit plot and the residuals cdf
data.fit.plot_fit()
data.fit.residuals_CDF()

# print the fit summary
data.fit.result["leastsq"]
# Out:
# <h2>Fit Result</h2> <p>Model: Model(_brownian)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>34</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>1978</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 2138.98321</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.08357812</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 162.767322</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 185.126688</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.96076771</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>Gamma</td><td style='text-align:left'> 3.1804e-11</td><td style='text-align:left'> 6.3762e-12</td><td style='text-align:left'>(20.05%)</td><td style='text-align:left'>1e-11</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>tau0</td><td style='text-align:left'> 144.462463</td><td style='text-align:left'> 14.7068322</td><td style='text-align:left'>(10.18%)</td><td style='text-align:left'>200.0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>f0</td><td style='text-align:left'> 8.23888678</td><td style='text-align:left'> 1.1057e-04</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>8.239</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>baseline</td><td style='text-align:left'> 13.4963765</td><td style='text-align:left'> 0.17397855</td><td style='text-align:left'>(1.29%)</td><td style='text-align:left'>14.40868686868687</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>Gamma</td><td style='text-align:left'>tau0</td><td style='text-align:right'>-0.9949</td></tr></table>

# %% [markdown]
# ## Use Bayesian methods to explore parameter distributions
#
# ### Maximum Log Likelihood Estimates

# %%
# define parameter bounds for Gamma, tau0, f0, and baseline
bounds = [(1e-16,1e-7),(1,5000),(4.5,11),(1,50)]

# find maximum og likelihood estimate
data.fit.max_likelihood(bounds)

print(data.fit.bayesian_result)
# Out:
# {'Gamma': 3.1804362951600435e-11, 'tau0': 144.46246299980783, 'f0': 8.238886784654381, 'baseline': 13.496376489559365}

# %% [markdown]
# ### MCMC

# %%
data.fit.MCMC(bounds, figpath = path)
# Out:
# Running emcee sampler...
# 100%|██████████| 2000/2000 [00:14<00:00, 141.54it/s]
# Plotting walkers...
# Calculating autocorrelation times...
# [11.5216363  12.17510855  2.02055289  4.8839738 ]
# Generating corner plots...
# Done.
